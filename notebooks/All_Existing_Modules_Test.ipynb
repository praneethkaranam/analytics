# %%
### All Imports go here

import os
import sys
import boto
from inspect import getmembers
from datetime import datetime
HOME = os.environ.get('HOME')
sys.path.append(HOME + "/comscore_processing")
sc.addPyFile(HOME + "/comscore_processing/utils.zip")
from utils.utils import apply_process_row
from utils.constants import *
from utils.session_aggregators import SessionAggregator
from utils.log_processors import UserProcessor
from utils.category_counts import site_combos_to_process,process_category_combos
from utils.page_site_counter import PageSiteCounter

# %%
### Data Declarations go here

data = sc.textFile("/home/analytics/comscore_processing/tests/TestSpark/sample_data/20160404")
header = sc.broadcast(data.first().strip().split('\t'))
sampleData = data.sample(False,0.01)

# %%
S3_FILE_PATTERN.format('20160404')
# Out:
# 's3n://msr-redshift/comscore_ctu_dump_url_dat_20160404_RDNA_*.dat.gz'

# %%
### All constants for data input and output

### Input format - Text file
S3_FILE_PATTERN.format('20160404')

### Output Pattern
### Data dhould have already been processed to get the data from the buckets

## Visitor level processing / First pass pattern - Parquet format data
S3_FIRST_PASS_PATTERN.format(log_date='2016-03-01',site='tasteofhome')

## Site and page counting / daily page view/site view counts - Parquet format data
S3_PAGE_COUNT_PATTERN.format(log_date="2016-04-05")
S3_SITE_COUNT_PATTERN.format(log_date="2016-04-05")

## gives output of all vids and sites visited by them. one vis and site per row - Parquet data
##[Row(ns_vid='1d1d68d4-6903-1097-0113-145934844600', log_date='2016-04-06', site='tasteofhome'),
## Row(ns_vid='aaa7ae17-2024-7090-1251-458873183000', log_date='2016-04-06', site='tasteofhome')]
userIdCountData = sqlContext.read.\
                        parquet("s3n://rdmsr-anl/daily_all_ids_by_site/2016-04-06/log_date=2016-04-06/site=tasteofhome/")
userIdCountData.take(10)

## Final pass pattern - First pass pattern data should exist to process final pass - text file
S3_VISITOR_FINAL_PATTERN.format(site="tasteofhome",start="2016-03-01",end="2016-03-31",source="parquet")

## Category Counting - Parquet data
S3_SITE_CAT_FILE_PATTERN % ("2015-12-01","_site-category-subcat")

# %%
### Data of S3_FILE_PATTERN
data_S3FilePattern = sc.textFile(S3_FILE_PATTERN.format('20160710'))
#data_S3FilePattern.take(2)
sampIpFilePat = data_S3FilePattern.sample(False,0.01)
header = sc.broadcast(data_S3FilePattern.first().strip().split('\t'))
header.value
# Out:
# ['ns_vid',
#  'ns_utc',
#  'name',
#  'ns_lda_mark_reason',
#  'referrer',
#  'ns_v_country',
#  'ns_v_city',
#  'content_id',
#  'ns_src_site',
#  'ns_jspageurl',
#  'ns_site',
#  '_site',
#  'category',
#  'subcat',
#  'subsubcat',
#  'subsubsubcat',
#  'content_type',
#  'content_name',
#  'ns_campaign',
#  'epid',
#  'internal_tracking_id',
#  'ns_search_term',
#  'ns_search_result',
#  'search_pg',
#  'search_pg_no',
#  'search_cat',
#  'search_pos',
#  'search_event',
#  'optin',
#  'optout',
#  'nl_name',
#  'nl_signup_event',
#  'pv_event',
#  'mpv_event',
#  'tellafriend_event',
#  'sweeps_entry_event',
#  'link_pos',
#  'link_page',
#  'link_name',
#  'exit_link',
#  'print_event',
#  'form_type',
#  'form_name',
#  'form_sub_event',
#  'slideshow_event',
#  'exit_link_event',
#  'comments_event',
#  'payment_type',
#  'is_mobile',
#  'login_status',
#  'rel_content',
#  'search_facet_term',
#  'search_facet_remove',
#  'form_sub_pref',
#  'page_no',
#  'partner_name',
#  'login_type',
#  'member_id',
#  'order_source',
#  'reg_source',
#  'mailing_id',
#  'dir_type',
#  'usr_agent',
#  'agent',
#  'login_event',
#  'email_event',
#  'new_reg_event',
#  'gate_pv_event',
#  'form_pg_no',
#  'dir_stf_event',
#  'rate_content_event',
#  'add_bookmark_event',
#  'sup_stf_event',
#  'create_folder_event',
#  'scrname_reg_event',
#  'slideshow_ad_event',
#  'prod_type',
#  'payment_event',
#  'renew_event',
#  'cancel_mag_event',
#  'cancel_ser_event',
#  'stf_count_event',
#  'add_groc_event',
#  'server_name',
#  'physical_pg_name',
#  'channel_level',
#  'pub_dt',
#  'social_share_event',
#  'link_target',
#  'prod_id',
#  'prod_view',
#  'email_blast_id',
#  'link_module',
#  'email_campaign',
#  'breadcrumb_level',
#  'breadcrumb_name',
#  'page_template',
#  'review_status',
#  'qualitative_feedback_text',
#  'star_rating_score',
#  'ns_event',
#  'ns_ti',
#  'ns_pageurl',
#  'ns_codeurl',
#  'ns_vid_class',
#  'type',
#  'time',
#  'ip',
#  'ns_clid',
#  'ns_fee',
#  'ns_linkname',
#  'ns_mchannel',
#  'ns_source',
#  'ns_brand',
#  'ns_client_id',
#  'ns_commerce',
#  'ns_order_id',
#  'ns_orderline_id',
#  'ns_prod_grp',
#  'ns_prod_id',
#  'ns_prod_price',
#  'ns_qty',
#  'ns_shop',
#  'ns_orderlines',
#  'promokey',
#  'sitename',
#  'slide_no',
#  'full_loading_time',
#  'innersize',
#  'html_loading_time',
#  'screen',
#  'nl_signup_count',
#  'nl_select_all_event',
#  'recipe_of_the_day_signup_event',
#  'weeknight_dinners_signup_event',
#  'holiday__celebration_signup_event',
#  'dessert_signup_event',
#  'slow_cooker__casserole_signup_event',
#  'healthy_signup_event',
#  'top_10_signup_event',
#  'cooking_school_signup_event',
#  'taste_of_home_special_edition_signup_event',
#  'back_to_school_signup_event',
#  'thanksgiving_countdown_signup_event',
#  'christmas_cookie_countdown_signup_event',
#  'country_woman_insider_signup_event',
#  'taste_of_home_signup_event',
#  'quick_dinner_signup_event',
#  'menusaver_signup_event',
#  'good__healthy_signup_event',
#  'light_dessert_signup_event',
#  'cookbook_insider_signup_event',
#  'cs_search_term',
#  'cs_search_event',
#  'breadcrumb',
#  'campaign',
#  'email_optin',
#  'digital_sub_event',
#  'exit_link_URL',
#  'gift_xsell_event',
#  'iPad_download_event',
#  'link_position',
#  'miss_issue_event',
#  'new_folder_name',
#  'new_recipe_submit_course',
#  'new_recipe_submit_cuisine',
#  'new_recipe_submit_holiday',
#  'new_recipe_submit_occasion',
#  'new_recipe_submit_prep',
#  'newsletter_optin',
#  'number_reviews_viewed',
#  'placement_location',
#  'popup_blocked',
#  'print_options_selected',
#  'print_preview_shown',
#  'rb_search_event',
#  'rb_search_term',
#  'recipe_rating',
#  'recipe_review_submit',
#  'recipient_deletion_event',
#  'recipient_entry_event',
#  'registration_process_type',
#  'ruid',
#  'rwd_template',
#  'save_folder_name',
#  'search_num_displayed',
#  'search_result_clicked',
#  'search_result_type',
#  'search_sort',
#  'ship_type',
#  'showdown_matchup',
#  'showdown_winner',
#  'sort_by_value',
#  'submit_to_contest',
#  'submit_to_pub',
#  'subscribe_event',
#  'subscription_term',
#  'subscription_type_change_event',
#  'sweeps_confirmation_type',
#  'web_recipe_title',
#  'web_recipe_url',
#  'upsell_event',
#  'share_email_event',
#  'send_me_copy_event',
#  'personal_message',
#  'autocomplete_event',
#  'autocomplete_recipe_event',
#  'recipe_deleted',
#  'the_family_handyman_onsite_signup_event',
#  'the_family_handyman_diy_tips__hints_signup_event',
#  'building_and_construction_professionals_tips__hints_signup_event',
#  'family_handyman_offers:_get_special_offers',
#  '_sweepstakes_and_discounts_from_the_fmaily_handyman._signup_event',
#  'birds__blooms_signup_event',
#  'reminisce_signup_event',
#  'garden_club_signup_event',
#  'recipe_of_the_day_newsletter_signup_event',
#  'newsletter_signup_event',
#  'age_check',
#  'conditions_selected',
#  'new_recipe_submit_pubs',
#  'new_recipe_submit_contests',
#  'new_recipe_submit_title',
#  'ns_ts',
#  'ns__p',
#  'plugins',
#  'adblock']

# %%
### First pass pattern - Output of Write parquet
data_S3FirstPass = sqlContext.read.parquet(S3_FIRST_PASS_PATTERN.format(log_date='2016-03-01',site='tasteofhome'))
data_S3FirstPass.take()[:1]
# Out:
# [Row(id='3fd45d12-2307-7017-1012-014201642930', ruid='dbb1641c-1420-4971-8b01-22315f912b1c', sessions=[{'user_agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36', 'records_in_session': '3', 'ip': 'dbb1641c-1420-4971-8b01-22315f912b1c', 'value_details': "{'content_id': {'30613': 2}, 'page_no': {'view all': 2}, 'partner_name': {'simple & delicious': 2}, 'type': {'hidden': 1, 'view': 2}, 'content_type': {'recipe detail': 2}, 'rel_content': {'related recipes': 2}}", 'categories_viewed': "[['recipes', 3]]", 'session_start_utc': '1456841130.16', 'epid': "['df5708cd5de442af52a21f5dbb50867cbc206ae0']", 'duration': '27', 'session_start_time': '2016-03-01 08:05:30', 'external_referrers': "['www.pinterest.com/']", 'time_zone': 'America/Chicago', 'location': "['41.7339', '-87.7795']", 'page_path': "[['www.tasteofhome.com/recipes/chinese-beef-casserole', 22]]"}], log_date='2016-03-01', site='tasteofhome')]

# %%
### Page Count - Unique page URL and number of visits for that on that day
data_S3PageCount = sqlContext.read.parquet(S3_PAGE_COUNT_PATTERN.format(log_date="2016-04-05"))
data_S3PageCount.toPandas()

# %%
### Site Count - Site and number of unique visitors
data_S3SiteCount = sqlContext.read.parquet(S3_SITE_COUNT_PATTERN.format(log_date="2016-04-05"))
data_S3SiteCount.toPandas()

# %%
## gives output of all vids and sites visited by them. one vis and site per row - Parquet data
##[Row(ns_vid='1d1d68d4-6903-1097-0113-145934844600', log_date='2016-04-06', site='tasteofhome'),
## Row(ns_vid='aaa7ae17-2024-7090-1251-458873183000', log_date='2016-04-06', site='tasteofhome')]
userIdCountData = sqlContext.read.\
                        parquet("s3n://rdmsr-anl/daily_all_ids_by_site/2016-04-06/log_date=2016-04-06/site=tasteofhome/")
userIdCountData.take(10)

# %%
## Final pass pattern - First pass pattern data should exist to process final pass - text file
data_S3FinalPattern = sc.textFile(S3_VISITOR_FINAL_PATTERN.format(site="tasteofhome",\
                                                                  start="2016-03-01",end="2016-03-31",source="parquet"))
data_S3FinalPattern.take(0)
# Out:
# ['216.53.142.2#48C66211\ttasteofhome\t1\t0\t1.0\t5.0\t0\tMobile Safari\tbutter:1:5,easy:1:5,fudge:1:5,peanut:1:5,recipes:1:5\tno orders\tno payments\t2016-03-27\t3\t\tno ehid\tno email\tno epid\t1\t\t0\t\tRV=1/RE=1459080435/RB=/RO=8/RU=http%3a%2f%2fwww.tasteofhome.com%2frecipes%2feasy-peanut-butter-fudge/RS=^ADAMAxZXvrgGBPJP6n9z4Hm197Bmy4-\t\t0\taa8aec29-626f-4517-b5f4-22b501680615\t0\t1\t\t0\t\t1\t\t0\t1\t\t3\t\t\t1\tiOS\t1\t1\t\t0\t\t0\t\t\t0\t5\t0\t1\t0',
#  '5a620820-2303-0105-0203-142417594900\ttasteofhome\t1\t1\t1.0\t5.0\t0\tChrome Mobile\tloaf:1:5,meat:1:5,mom:1:5,recipes:1:5\tno orders\tno payments\t2016-03-02\t28\t\tno ehid\tno email\tno epid\t1\t\t0\t\t\t\t0\t9c558b1f-927e-4801-a50c-5e8c36addc1c\t0\t1\t\t0\t\t1\t\t0\t1\t\t28\t\t\t1\tAndroid\t1\t1\t\t0\t\t0\t\t\t0\t5\t1\t0\t0']

# %%
### Headers explaining the above data
sa = SessionAggregator(datetime(2016, 3, 1), 
        datetime(2016, 3, 31))
header = ['visitor_id', 'site']
for member in getmembers(sa):
    if callable(member[1]) and not member[0].startswith('_'):
        header.append(member[0])
header = sc.broadcast(header)
header.value
# Out:
# ['visitor_id',
#  'site',
#  'abandon_indicator',
#  'afternoon_visit_indicator',
#  'average_page_views_per_visit',
#  'average_visit_time_per_category',
#  'average_visit_time_per_day',
#  'average_visit_time_spent',
#  'bing_referral',
#  'browser',
#  'closed_hc_popup',
#  'content_terms',
#  'date_of_last_order',
#  'date_of_last_payment_event',
#  'date_of_last_visit',
#  'days_since_last_abandon',
#  'days_since_last_customer_support_visit',
#  'ehid',
#  'email',
#  'epid',
#  'evening_visit_indicator',
#  'facebook_content_terms',
#  'facebook_referral',
#  'first_external_referrer_domain_to_site',
#  'first_internal_referrer_to_site',
#  'google_plus_content_terms',
#  'google_referrel',
#  'healthcare_conditions_selected',
#  'ip_address',
#  'is_bot',
#  'is_mobile',
#  'list_of_newsletters',
#  'lunch_visit_indicator',
#  'mean_time_between_visits',
#  'morning_visit_indicator',
#  'most_frequent_referrer',
#  'newsletter_signup_indicator',
#  'night_owl_visit_indicator',
#  'number_days_since_first_visit',
#  'number_days_since_last_visit',
#  'number_of_order_abandons',
#  'number_of_orders',
#  'number_of_visits',
#  'operating_system',
#  'overall_category_coverage',
#  'page_views',
#  'pages_to_order',
#  'pinterest_content_terms',
#  'pinterest_referral',
#  'ruid',
#  'session_times',
#  'site_primary_visit_day_of_week',
#  'submitted_hc_popup',
#  'subscription_indicator',
#  'survey_taker_indicator',
#  'twitter_content_terms',
#  'twitter_referral',
#  'visit_total_time_spent',
#  'weekday_visit_indicator',
#  'weekend_visit_indicator',
#  'yahoo_referral']

# %%
### Map header and values of Final Pattern data

def getMappedData(x):
    splittedRow = x.split('\t')
    x = dict(zip(header.value[:len(splittedRow)], splittedRow))
    return x

def mapData(visitorFinalPassData):
    vData = visitorFinalPassData.map(getMappedData)
    return vData
finalMappedData = mapData(data_S3FinalPattern)
finalMappedData.take(2)

# %%
# sends mail if log date data is not available.
# if available returns data and header
data,header = get_log_date('20160406',sc)

# %%
# writes log date to dyname saying the dates are processed
conn = DynamoDBConnection()
record_log_date("2016-04-06","site_category_counts", conn = conn)

# %%
processed = apply_process_row(sampIpFilePat, header, 15)
processed.take(15)[:3]
# Out:
# [(('100.34.173.161#562B4D10', 'familyhandyman'),
#   [{'_site': 'familyhandyman',
#     '_sweepstakes_and_discounts_from_the_fmaily_handyman._signup_event': '',
#     'adblock': '',
#     'add_bookmark_event': '',
#     'add_groc_event': '',
#     'age_check': '',
#     'agent': 'Mozilla/5.0 (iPad; CPU OS 9_3_2 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13F69 Safari/601.1',
#     'autocomplete_event': '',
#     'autocomplete_recipe_event': '',
#     'back_to_school_signup_event': '',
#     'birds__blooms_signup_event': '',
#     'breadcrumb': '',
#     'breadcrumb_level': '',
#     'breadcrumb_name': '',
#     'building_and_construction_professionals_tips__hints_signup_event': '',
#     'campaign': '',
#     'cancel_mag_event': '',
#     'cancel_ser_event': '',
#     'category': 'skills',
#     'channel_level': '',
#     'christmas_cookie_countdown_signup_event': '',
#     'comments_event': '',
#     'conditions_selected': '',
#     'content_id': '185294',
#     'content_name': '',
#     'content_type': '36',
#     'cookbook_insider_signup_event': '',
#     'cooking_school_signup_event': '',
#     'country_woman_insider_signup_event': '',
#     'create_folder_event': '',
#     'cs_search_event': '',
#     'cs_search_term': '',
#     'dessert_signup_event': '',
#     'digital_sub_event': '',
#     'dir_stf_event': '',
#     'dir_type': '',
#     'email_blast_id': '',
#     'email_campaign': '',
#     'email_event': '',
#     'email_optin': '',
#     'epid': '',
#     'exit_link': '',
#     'exit_link_URL': '',
#     'exit_link_event': '',
#     'family_handyman_offers:_get_special_offers': '',
#     'form_name': '',
#     'form_pg_no': '',
#     'form_sub_event': '',
#     'form_sub_pref': '',
#     'form_type': '',
#     'full_loading_time': '',
#     'garden_club_signup_event': '',
#     'gate_pv_event': '',
#     'gift_xsell_event': '',
#     'good__healthy_signup_event': '',
#     'healthy_signup_event': '',
#     'holiday__celebration_signup_event': '',
#     'html_loading_time': '',
#     'iPad_download_event': '',
#     'innersize': '',
#     'internal_tracking_id': '',
#     'ip': '100.34.173.161',
#     'is_mobile': '',
#     'light_dessert_signup_event': '',
#     'link_module': '',
#     'link_name': 'overview',
#     'link_page': '/plumbing/drain-repair/unclog-a-bathroom-sink-without-chemicals/view-all',
#     'link_pos': 'intro',
#     'link_position': '',
#     'link_target': 'step1',
#     'login_event': '',
#     'login_status': '',
#     'login_type': '',
#     'mailing_id': '',
#     'member_id': '',
#     'menusaver_signup_event': '',
#     'miss_issue_event': '',
#     'mpv_event': '',
#     'name': 'plumbing.drain-repair.unclog-a-bathroom-sink-without-chemicals.view-all',
#     'new_folder_name': '',
#     'new_recipe_submit_contests': '',
#     'new_recipe_submit_course': '',
#     'new_recipe_submit_cuisine': '',
#     'new_recipe_submit_holiday': '',
#     'new_recipe_submit_occasion': '',
#     'new_recipe_submit_prep': '',
#     'new_recipe_submit_pubs': '',
#     'new_recipe_submit_title': '',
#     'new_reg_event': '',
#     'newsletter_optin': '',
#     'newsletter_signup_event': '',
#     'nl_name': '',
#     'nl_select_all_event': '',
#     'nl_signup_count': '',
#     'nl_signup_event': '',
#     'ns__p': '',
#     'ns_brand': '',
#     'ns_campaign': '',
#     'ns_clid': '',
#     'ns_client_id': '',
#     'ns_codeurl': 'http://www.familyhandyman.com/plumbing/drain-repair/unclog-a-bathroom-sink-without-chemicals/view-all',
#     'ns_commerce': '',
#     'ns_event': '',
#     'ns_fee': '',
#     'ns_jspageurl': 'http://www.familyhandyman.com/plumbing/drain-repair/unclog-a-bathroom-sink-without-chemicals/view-all',
#     'ns_lda_mark_reason': '',
#     'ns_linkname': '',
#     'ns_mchannel': '',
#     'ns_order_id': '',
#     'ns_orderline_id': '',
#     'ns_orderlines': '',
#     'ns_pageurl': 'http://www.familyhandyman.com/plumbing/drain-repair/unclog-a-bathroom-sink-without-chemicals/view-all',
#     'ns_prod_grp': '',
#     'ns_prod_id': '',
#     'ns_prod_price': '',
#     'ns_qty': '',
#     'ns_search_result': '',
#     'ns_search_term': '',
#     'ns_shop': '',
#     'ns_site': '',
#     'ns_source': '',
#     'ns_src_site': '',
#     'ns_ti': 'Unclog a Bathroom Sink Without Chemicals | The Family Handyman',
#     'ns_ts': '',
#     'ns_utc': '1468147598503',
#     'ns_v_city': 'philadelphia',
#     'ns_v_country': 'United States',
#     'ns_vid': '100.34.173.161#562B4D10',
#     'ns_vid_class': 'ip',
#     'number_reviews_viewed': '',
#     'optin': '',
#     'optout': '',
#     'order_source': '',
#     'page_no': '',
#     'page_template': 'article detail',
#     'partner_name': '',
#     'payment_event': '',
#     'payment_type': '',
#     'personal_message': '',
#     'physical_pg_name': '',
#     'placement_location': '',
#     'plugins': '',
#     'popup_blocked': '',
#     'print_event': '',
#     'print_options_selected': '',
#     'print_preview_shown': '',
#     'prod_id': '',
#     'prod_type': '',
#     'prod_view': '',
#     'promokey': '',
#     'pub_dt': '',
#     'pv_event': '',
#     'qualitative_feedback_text': '',
#     'quick_dinner_signup_event': '',
#     'rate_content_event': '',
#     'rb_search_event': '',
#     'rb_search_term': '',
#     'recipe_deleted': '',
#     'recipe_of_the_day_newsletter_signup_event': '',
#     'recipe_of_the_day_signup_event': '',
#     'recipe_rating': '',
#     'recipe_review_submit': '',
#     'recipient_deletion_event': '',
#     'recipient_entry_event': '',
#     'referrer': 'https://www.google.com/',
#     'reg_source': '',
#     'registration_process_type': '',
#     'rel_content': '',
#     'reminisce_signup_event': '',
#     'renew_event': '',
#     'review_status': '',
#     'ruid': '97c827a2-3d1e-4179-af3b-afd73bdcecae',
#     'rwd_template': 'tablet',
#     'save_folder_name': '',
#     'screen': '',
#     'scrname_reg_event': '',
#     'search_cat': '',
#     'search_event': '',
#     'search_facet_remove': '',
#     'search_facet_term': '',
#     'search_num_displayed': '',
#     'search_pg': '',
#     'search_pg_no': '',
#     'search_pos': '',
#     'search_result_clicked': '',
#     'search_result_type': '',
#     'search_sort': '',
#     'send_me_copy_event': '',
#     'server_name': '',
#     'share_email_event': '',
#     'ship_type': '',
#     'showdown_matchup': '',
#     'showdown_winner': '',
#     'sitename': '',
#     'slide_no': '',
#     'slideshow_ad_event': '',
#     'slideshow_event': '',
#     'slow_cooker__casserole_signup_event': '',
#     'social_share_event': '',
#     'sort_by_value': '',
#     'star_rating_score': '',
#     'stf_count_event': '',
#     'subcat': 'plumbing',
#     'submit_to_contest': '',
#     'submit_to_pub': '',
#     'subscribe_event': '',
#     'subscription_term': '',
#     'subscription_type_change_event': '',
#     'subsubcat': '',
#     'subsubsubcat': '',
#     'sup_stf_event': '',
#     'sweeps_confirmation_type': '',
#     'sweeps_entry_event': '',
#     'taste_of_home_signup_event': '',
#     'taste_of_home_special_edition_signup_event': '',
#     'tellafriend_event': '',
#     'thanksgiving_countdown_signup_event': '',
#     'the_family_handyman_diy_tips__hints_signup_event': '',
#     'the_family_handyman_onsite_signup_event': '',
#     'time': '24398503',
#     'top_10_signup_event': '',
#     'type': 'hidden',
#     'upsell_event': '',
#     'usr_agent': '',
#     'web_recipe_title': '',
#     'web_recipe_url': '',
#     'weeknight_dinners_signup_event': ''}]),
#  (('12d50b3a-1110-1190-2300-414449648490', 'tasteofhome'),
#   [{'_site': 'tasteofhome',
#     '_sweepstakes_and_discounts_from_the_fmaily_handyman._signup_event': '',
#     'adblock': '',
#     'add_bookmark_event': '',
#     'add_groc_event': '',
#     'age_check': '',
#     'agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 UBrowser/5.6.13108.1008 Safari/537.36',
#     'autocomplete_event': '',
#     'autocomplete_recipe_event': '',
#     'back_to_school_signup_event': '',
#     'birds__blooms_signup_event': '',
#     'breadcrumb': '',
#     'breadcrumb_level': '',
#     'breadcrumb_name': '',
#     'building_and_construction_professionals_tips__hints_signup_event': '',
#     'campaign': '',
#     'cancel_mag_event': '',
#     'cancel_ser_event': '',
#     'category': 'recipes',
#     'channel_level': '',
#     'christmas_cookie_countdown_signup_event': '',
#     'comments_event': '',
#     'conditions_selected': '',
#     'content_id': '',
#     'content_name': '30 desserts made in a 13x9 pan',
#     'content_type': 'slideshow',
#     'cookbook_insider_signup_event': '',
#     'cooking_school_signup_event': '',
#     'country_woman_insider_signup_event': '',
#     'create_folder_event': '',
#     'cs_search_event': '',
#     'cs_search_term': '',
#     'dessert_signup_event': '',
#     'digital_sub_event': '',
#     'dir_stf_event': '',
#     'dir_type': '',
#     'email_blast_id': '',
#     'email_campaign': '',
#     'email_event': '',
#     'email_optin': '',
#     'epid': 'e227154eaa06d07b325ae0c39e0a9dca8287f80c',
#     'exit_link': '',
#     'exit_link_URL': '',
#     'exit_link_event': '',
#     'family_handyman_offers:_get_special_offers': '',
#     'form_name': '',
#     'form_pg_no': '',
#     'form_sub_event': '',
#     'form_sub_pref': '',
#     'form_type': '',
#     'full_loading_time': '',
#     'garden_club_signup_event': '',
#     'gate_pv_event': '',
#     'gift_xsell_event': '',
#     'good__healthy_signup_event': '',
#     'healthy_signup_event': '',
#     'holiday__celebration_signup_event': '',
#     'html_loading_time': '',
#     'iPad_download_event': '',
#     'innersize': '',
#     'internal_tracking_id': '',
#     'ip': '103.41.33.9',
#     'is_mobile': '',
#     'light_dessert_signup_event': '',
#     'link_module': 'slides',
#     'link_name': 'next',
#     'link_page': '/recipes/course/desserts/30-desserts-made-in-a-13-9-pan',
#     'link_pos': 'main slides',
#     'link_position': '',
#     'link_target': '',
#     'login_event': '',
#     'login_status': '',
#     'login_type': '',
#     'mailing_id': '',
#     'member_id': '',
#     'menusaver_signup_event': '',
#     'miss_issue_event': '',
#     'mpv_event': '',
#     'name': 'recipes.course.desserts.30-desserts-made-in-a-13-9-pan',
#     'new_folder_name': '',
#     'new_recipe_submit_contests': '',
#     'new_recipe_submit_course': '',
#     'new_recipe_submit_cuisine': '',
#     'new_recipe_submit_holiday': '',
#     'new_recipe_submit_occasion': '',
#     'new_recipe_submit_prep': '',
#     'new_recipe_submit_pubs': '',
#     'new_recipe_submit_title': '',
#     'new_reg_event': '',
#     'newsletter_optin': '',
#     'newsletter_signup_event': '',
#     'nl_name': '',
#     'nl_select_all_event': '',
#     'nl_signup_count': '',
#     'nl_signup_event': '',
#     'ns__p': '',
#     'ns_brand': '',
#     'ns_campaign': '',
#     'ns_clid': '',
#     'ns_client_id': '',
#     'ns_codeurl': 'http://www.tasteofhome.com/recipes/course/desserts/30-desserts-made-in-a-13-9-pan?pmcode=&_cmp=TOHContentTOH&_ebid=TOHContentTOH7/9/2016&_mid=104813&ehid=e227154eaa06d07b325ae0c39e0a9dca8287f80c',
#     'ns_commerce': '',
#     'ns_event': '',
#     'ns_fee': '',
#     'ns_jspageurl': 'http://www.tasteofhome.com/recipes/course/desserts/30-desserts-made-in-a-13-9-pan?pmcode=&_cmp=tohcontenttoh&_ebid=tohcontenttoh7/9/2016&_mid=104813&ehid=e227154eaa06d07b325ae0c39e0a9dca8287f80c#30',
#     'ns_lda_mark_reason': '',
#     'ns_linkname': '',
#     'ns_mchannel': '',
#     'ns_order_id': '',
#     'ns_orderline_id': '',
#     'ns_orderlines': '',
#     'ns_pageurl': 'http://www.tasteofhome.com/recipes/course/desserts/30-desserts-made-in-a-13-9-pan?pmcode=&_cmp=TOHContentTOH&_ebid=TOHContentTOH7/9/2016&_mid=104813&ehid=e227154eaa06d07b325ae0c39e0a9dca8287f80c',
#     'ns_prod_grp': '',
#     'ns_prod_id': '',
#     'ns_prod_price': '',
#     'ns_qty': '',
#     'ns_search_result': '',
#     'ns_search_term': '',
#     'ns_shop': '',
#     'ns_site': '',
#     'ns_source': '',
#     'ns_src_site': '',
#     'ns_ti': '30 desserts made in a 13x9 pan | taste of home',
#     'ns_ts': '',
#     'ns_utc': '1468126348648',
#     'ns_v_city': 'thane',
#     'ns_v_country': 'India',
#     'ns_vid': '12d50b3a-1110-1190-2300-414449648490',
#     'ns_vid_class': 'cookie',
#     'number_reviews_viewed': '',
#     'optin': '',
#     'optout': '',
#     'order_source': '',
#     'page_no': '',
#     'page_template': 'slideshow',
#     'partner_name': '',
#     'payment_event': '',
#     'payment_type': '',
#     'personal_message': '',
#     'physical_pg_name': '',
#     'placement_location': '',
#     'plugins': '',
#     'popup_blocked': '',
#     'print_event': '',
#     'print_options_selected': '',
#     'print_preview_shown': '',
#     'prod_id': '',
#     'prod_type': '',
#     'prod_view': '',
#     'promokey': '',
#     'pub_dt': '',
#     'pv_event': '',
#     'qualitative_feedback_text': '',
#     'quick_dinner_signup_event': '',
#     'rate_content_event': '',
#     'rb_search_event': '',
#     'rb_search_term': '',
#     'recipe_deleted': '',
#     'recipe_of_the_day_newsletter_signup_event': '',
#     'recipe_of_the_day_signup_event': '',
#     'recipe_rating': '',
#     'recipe_review_submit': '',
#     'recipient_deletion_event': '',
#     'recipient_entry_event': '',
#     'referrer': '',
#     'reg_source': '',
#     'registration_process_type': '',
#     'rel_content': '',
#     'reminisce_signup_event': '',
#     'renew_event': '',
#     'review_status': '',
#     'ruid': '3011358f-f462-4183-ad6f-bc86926288d4',
#     'rwd_template': '',
#     'save_folder_name': '',
#     'screen': '',
#     'scrname_reg_event': '',
#     'search_cat': '',
#     'search_event': '',
#     'search_facet_remove': '',
#     'search_facet_term': '',
#     'search_num_displayed': '',
#     'search_pg': '',
#     'search_pg_no': '',
#     'search_pos': '',
#     'search_result_clicked': '',
#     'search_result_type': '',
#     'search_sort': '',
#     'send_me_copy_event': '',
#     'server_name': '',
#     'share_email_event': '',
#     'ship_type': '',
#     'showdown_matchup': '',
#     'showdown_winner': '',
#     'sitename': '',
#     'slide_no': '',
#     'slideshow_ad_event': '',
#     'slideshow_event': 'true',
#     'slow_cooker__casserole_signup_event': '',
#     'social_share_event': '',
#     'sort_by_value': '',
#     'star_rating_score': '',
#     'stf_count_event': '',
#     'subcat': 'course',
#     'submit_to_contest': '',
#     'submit_to_pub': '',
#     'subscribe_event': '',
#     'subscription_term': '',
#     'subscription_type_change_event': '',
#     'subsubcat': 'desserts',
#     'subsubsubcat': '30-desserts-made-in-a-13-9-pan',
#     'sup_stf_event': '',
#     'sweeps_confirmation_type': '',
#     'sweeps_entry_event': '',
#     'taste_of_home_signup_event': '',
#     'taste_of_home_special_edition_signup_event': '',
#     'tellafriend_event': '',
#     'thanksgiving_countdown_signup_event': '',
#     'the_family_handyman_diy_tips__hints_signup_event': '',
#     'the_family_handyman_onsite_signup_event': '',
#     'time': '3148648',
#     'top_10_signup_event': '',
#     'type': 'view',
#     'upsell_event': '',
#     'usr_agent': '',
#     'web_recipe_title': '',
#     'web_recipe_url': '',
#     'weeknight_dinners_signup_event': ''}]),
#  (('b4112216-5015-3018-0141-468180747000', 'familyhandyman'),
#   [{'_site': 'familyhandyman',
#     '_sweepstakes_and_discounts_from_the_fmaily_handyman._signup_event': '',
#     'adblock': '',
#     'add_bookmark_event': '',
#     'add_groc_event': '',
#     'age_check': '',
#     'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
#     'autocomplete_event': '',
#     'autocomplete_recipe_event': '',
#     'back_to_school_signup_event': '',
#     'birds__blooms_signup_event': '',
#     'breadcrumb': '',
#     'breadcrumb_level': '',
#     'breadcrumb_name': '',
#     'building_and_construction_professionals_tips__hints_signup_event': '',
#     'campaign': '',
#     'cancel_mag_event': '',
#     'cancel_ser_event': '',
#     'category': 'outdoors',
#     'channel_level': 'outdoors-3',
#     'christmas_cookie_countdown_signup_event': '',
#     'comments_event': '',
#     'conditions_selected': '',
#     'content_id': '176089',
#     'content_name': 'how to build a cedar deck railing with glass',
#     'content_type': 'project',
#     'cookbook_insider_signup_event': '',
#     'cooking_school_signup_event': '',
#     'country_woman_insider_signup_event': '',
#     'create_folder_event': '',
#     'cs_search_event': '',
#     'cs_search_term': '',
#     'dessert_signup_event': '',
#     'digital_sub_event': '',
#     'dir_stf_event': '',
#     'dir_type': '',
#     'email_blast_id': '',
#     'email_campaign': '',
#     'email_event': '',
#     'email_optin': '',
#     'epid': '',
#     'exit_link': '',
#     'exit_link_URL': '',
#     'exit_link_event': '',
#     'family_handyman_offers:_get_special_offers': '',
#     'form_name': '',
#     'form_pg_no': '',
#     'form_sub_event': '',
#     'form_sub_pref': '',
#     'form_type': '',
#     'full_loading_time': '',
#     'garden_club_signup_event': '',
#     'gate_pv_event': '',
#     'gift_xsell_event': '',
#     'good__healthy_signup_event': '',
#     'healthy_signup_event': '',
#     'holiday__celebration_signup_event': '',
#     'html_loading_time': '',
#     'iPad_download_event': '',
#     'innersize': '',
#     'internal_tracking_id': '',
#     'ip': '184.100.100.73',
#     'is_mobile': '',
#     'light_dessert_signup_event': '',
#     'link_module': '',
#     'link_name': '',
#     'link_page': '',
#     'link_pos': '',
#     'link_position': '',
#     'link_target': '',
#     'login_event': '',
#     'login_status': 'logged out',
#     'login_type': '',
#     'mailing_id': '',
#     'member_id': '',
#     'menusaver_signup_event': '',
#     'miss_issue_event': '',
#     'mpv_event': '',
#     'name': 'tfh.how to build a cedar deck railing with glass (/decks/railing/how-to-build-a-cedar-deck-railing-with-glass/view-all)',
#     'new_folder_name': '',
#     'new_recipe_submit_contests': '',
#     'new_recipe_submit_course': '',
#     'new_recipe_submit_cuisine': '',
#     'new_recipe_submit_holiday': '',
#     'new_recipe_submit_occasion': '',
#     'new_recipe_submit_prep': '',
#     'new_recipe_submit_pubs': '',
#     'new_recipe_submit_title': '',
#     'new_reg_event': '',
#     'newsletter_optin': '',
#     'newsletter_signup_event': '',
#     'nl_name': '',
#     'nl_select_all_event': '',
#     'nl_signup_count': '',
#     'nl_signup_event': '',
#     'ns__p': '',
#     'ns_brand': '',
#     'ns_campaign': '',
#     'ns_clid': '',
#     'ns_client_id': '',
#     'ns_codeurl': 'http://www.familyhandyman.com/decks/railing/how-to-build-a-cedar-deck-railing-with-glass/view-all',
#     'ns_commerce': '',
#     'ns_event': '',
#     'ns_fee': '',
#     'ns_jspageurl': 'http://www.familyhandyman.com/decks/railing/how-to-build-a-cedar-deck-railing-with-glass/view-all',
#     'ns_lda_mark_reason': '',
#     'ns_linkname': '',
#     'ns_mchannel': '',
#     'ns_order_id': '',
#     'ns_orderline_id': '',
#     'ns_orderlines': '',
#     'ns_pageurl': 'http://www.familyhandyman.com/decks/railing/how-to-build-a-cedar-deck-railing-with-glass/view-all',
#     'ns_prod_grp': '',
#     'ns_prod_id': '',
#     'ns_prod_price': '',
#     'ns_qty': '',
#     'ns_search_result': '',
#     'ns_search_term': '',
#     'ns_shop': '',
#     'ns_site': '',
#     'ns_source': '',
#     'ns_src_site': '',
#     'ns_ti': 'How to Build a Cedar Deck Railing with Glass | The Family Handyman',
#     'ns_ts': '',
#     'ns_utc': '1468180747616',
#     'ns_v_city': 'minneapolis',
#     'ns_v_country': 'United States',
#     'ns_vid': 'b4112216-5015-3018-0141-468180747000',
#     'ns_vid_class': 'cookie',
#     'number_reviews_viewed': '',
#     'optin': '',
#     'optout': '',
#     'order_source': '',
#     'page_no': '',
#     'page_template': 'project',
#     'partner_name': '',
#     'payment_event': '',
#     'payment_type': '',
#     'personal_message': '',
#     'physical_pg_name': 'projects/index',
#     'placement_location': '',
#     'plugins': '',
#     'popup_blocked': '',
#     'print_event': '',
#     'print_options_selected': '',
#     'print_preview_shown': '',
#     'prod_id': '',
#     'prod_type': '',
#     'prod_view': '',
#     'promokey': '',
#     'pub_dt': '',
#     'pv_event': '',
#     'qualitative_feedback_text': '',
#     'quick_dinner_signup_event': '',
#     'rate_content_event': '',
#     'rb_search_event': '',
#     'rb_search_term': '',
#     'recipe_deleted': '',
#     'recipe_of_the_day_newsletter_signup_event': '',
#     'recipe_of_the_day_signup_event': '',
#     'recipe_rating': '',
#     'recipe_review_submit': '',
#     'recipient_deletion_event': '',
#     'recipient_entry_event': '',
#     'referrer': 'http://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=0ahUKEwjVztu51-nNAhWFeCYKHc5LATYQFghLMAA&url=http%3A%2F%2Fwww.familyhandyman.com%2Fdecks%2Frailing%2Fhow-to-build-a-cedar-deck-railing-with-glass%2Fview-all&usg=AFQjCNGFFO-bcT2LIMaIq05C5G0vivypNQ',
#     'reg_source': '',
#     'registration_process_type': '',
#     'rel_content': '',
#     'reminisce_signup_event': '',
#     'renew_event': '',
#     'review_status': '',
#     'ruid': '3e92a17f-ae14-405c-b726-3a14c6d7f155',
#     'rwd_template': '',
#     'save_folder_name': '',
#     'screen': '',
#     'scrname_reg_event': '',
#     'search_cat': '',
#     'search_event': '',
#     'search_facet_remove': '',
#     'search_facet_term': '',
#     'search_num_displayed': '',
#     'search_pg': '',
#     'search_pg_no': '',
#     'search_pos': '',
#     'search_result_clicked': '',
#     'search_result_type': '',
#     'search_sort': '',
#     'send_me_copy_event': '',
#     'server_name': 'uspvldmz8k02',
#     'share_email_event': '',
#     'ship_type': '',
#     'showdown_matchup': '',
#     'showdown_winner': '',
#     'sitename': '',
#     'slide_no': '',
#     'slideshow_ad_event': '',
#     'slideshow_event': '',
#     'slow_cooker__casserole_signup_event': '',
#     'social_share_event': '',
#     'sort_by_value': '',
#     'star_rating_score': '',
#     'stf_count_event': '',
#     'subcat': 'decks',
#     'submit_to_contest': '',
#     'submit_to_pub': '',
#     'subscribe_event': '',
#     'subscription_term': '',
#     'subscription_type_change_event': '',
#     'subsubcat': 'deck railing',
#     'subsubsubcat': '',
#     'sup_stf_event': '',
#     'sweeps_confirmation_type': '',
#     'sweeps_entry_event': '',
#     'taste_of_home_signup_event': '',
#     'taste_of_home_special_edition_signup_event': '',
#     'tellafriend_event': '',
#     'thanksgiving_countdown_signup_event': '',
#     'the_family_handyman_diy_tips__hints_signup_event': '',
#     'the_family_handyman_onsite_signup_event': '',
#     'time': '57547616',
#     'top_10_signup_event': '',
#     'type': 'view',
#     'upsell_event': '',
#     'usr_agent': '',
#     'web_recipe_title': '',
#     'web_recipe_url': '',
#     'weeknight_dinners_signup_event': ''}])]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7abb2bc7bbec> in <module>()
# ----> 1 processed.take(15)[:3]
#
# NameError: name 'processed' is not defined

# %%
## Visitor first pass processing through functions
#processed = apply_process_row(data_S3FilePattern, header, 15)
dt = datetime(2015,5,9)
up = UserProcessor(dt)
data = processed.mapValues(up).map(lambda x: x[1], True)
data.take(5)[1]
filtered_data = data.filter(lambda x: len(x[3])>1)
filtered_data.take(5)
# Out:
# [('675e8a33-1240-1060-1740-811435096939',
#   'rd',
#   '2015-05-09',
#   [{'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['culture', 5]],
#     'category_page_path': [['culture',
#       'www.rd.com/advice/work-career/how-to-look-smart/9/']],
#     'city': 'makati city',
#     'country': 'Philippines',
#     'duration': 5,
#     'event_details': {'pv_event': {'true': 1}, 'slideshow_event': {'true': 1}},
#     'internal_referrers': ['www.rd.com/advice/work-career/how-to-look-smart/1/'],
#     'ip': '112.205.193.50',
#     'location': ['14.5833', '120.9667'],
#     'page_path': [['www.rd.com/advice/work-career/how-to-look-smart/9/', 5]],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-10 18:03:24',
#     'session_start_utc': '1468145004.392',
#     'time_zone': 'Asia/Manila',
#     'user_agent': 'Mozilla/5.0 (Linux; Android 5.0; SM-N9005 Build/LRX21V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.81 Mobile Safari/537.36',
#     'value_details': {'content_id': {'170542': 1},
#      'content_type': {'slideshow': 1},
#      'link_module': {'slides': 1},
#      'link_name': {'next': 1},
#      'link_page': {"Daily Habits That Make You Look Smart | Reader's Digest": 1},
#      'link_pos': {'header': 1},
#      'page_template': {'slideshow': 1},
#      'pub_dt': {'2016-06-13': 1},
#      'type': {'view': 1}}},
#    {'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['culture', 5]],
#     'category_page_path': [['culture',
#       'www.rd.com/advice/work-career/how-to-look-smart/10/']],
#     'city': 'makati city',
#     'country': 'Philippines',
#     'duration': 5,
#     'event_details': {'pv_event': {'true': 1}, 'slideshow_event': {'true': 1}},
#     'ip': '112.205.193.50',
#     'location': ['14.5833', '120.9667'],
#     'page_path': [['www.rd.com/advice/work-career/how-to-look-smart/10/', 5]],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-10 21:54:57',
#     'session_start_utc': '1468151950.796',
#     'time_zone': 'Asia/Manila',
#     'user_agent': 'Mozilla/5.0 (Linux; Android 5.0; SM-N9005 Build/LRX21V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.81 Mobile Safari/537.36',
#     'value_details': {'content_id': {'170542': 1},
#      'content_type': {'slideshow': 1},
#      'pub_dt': {'2016-06-13': 1},
#      'type': {'view': 1}}}],
#   '6edc908d-9318-2f3f-82ab-e35b3bff11ad'),
#  ('ebeb9911-7023-9018-9011-414681451520',
#   'rd',
#   '2015-05-09',
#   [{'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['home~cleaning and organizing', 5]],
#     'category_page_path': [['home~cleaning and organizing',
#       'www.rd.com/home/cleaning-organizing/useful-bathroom-storage-tips/1/']],
#     'city': 'bangalore',
#     'country': 'India',
#     'duration': 5,
#     'event_details': {'pv_event': {'true': 1}, 'slideshow_event': {'true': 1}},
#     'internal_referrers': ['www.rd.com/home/cleaning-organizing/organized-spotless-house/10/'],
#     'ip': '117.192.55.153',
#     'location': ['12.9833', '77.5833'],
#     'page_path': [['www.rd.com/home/cleaning-organizing/useful-bathroom-storage-tips/1/',
#       5]],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-10 18:31:08',
#     'session_start_utc': '1468153171.717',
#     'time_zone': 'Asia/Kolkata',
#     'user_agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
#     'value_details': {'content_id': {'165372': 1},
#      'content_type': {'slideshow': 1},
#      'pub_dt': {'2016-05-31': 1},
#      'type': {'view': 1}}},
#    {'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['home~cleaning and organizing', 986]],
#     'category_page_path': [['home~cleaning and organizing',
#       'www.rd.com/home/cleaning-organizing/13-common-items-for-getting-rid-of-ants/3/']],
#     'city': 'bangalore',
#     'country': 'India',
#     'duration': 991,
#     'event_details': {'pv_event': {'true': 2}, 'slideshow_event': {'true': 2}},
#     'ip': '117.192.55.153',
#     'location': ['12.9833', '77.5833'],
#     'page_path': [['www.rd.com/home/cleaning-organizing/13-common-items-for-getting-rid-of-ants/3/',
#       986]],
#     'records_in_session': 2,
#     'session_start_time': '2016-07-10 16:51:27',
#     'session_start_utc': '1468149687.912',
#     'time_zone': 'Asia/Kolkata',
#     'user_agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
#     'value_details': {'content_id': {'124274': 1, '136846': 1},
#      'content_type': {'slideshow': 2},
#      'link_module': {'slides': 2},
#      'link_name': {'next': 2},
#      'link_page': {"12 Storage Hacks to Banish Clutter\xa0|\xa0Reader's Digest": 1,
#       "How to Get Rid of Ants\xa0|\xa0Reader's Digest": 1},
#      'link_pos': {'footer': 1, 'header': 1},
#      'page_template': {'slideshow': 2},
#      'pub_dt': {'2015-02-24': 1, '2015-09-29': 1},
#      'type': {'view': 2}}}],
#   'b4d9668b-c591-89a7-cd01-ad939fd15024'),
#  ('431173be-6606-1016-3019-414513087350',
#   'tasteofhome',
#   '2015-05-09',
#   [{'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['recipes~course~desserts~lemonade-desserts', 1094]],
#     'category_page_path': [['recipes~course~desserts~lemonade-desserts',
#       'www.tasteofhome.com/recipes/course/desserts/lemonade-desserts']],
#     'city': 'temple',
#     'consolidated_query_strings': {'_cmp': ['recipeoftheday',
#       'recipeoftheday'],
#      '_ebid': ['recipeoftheday7/8/2016', 'recipeoftheday7/6/2016'],
#      '_mid': ['104749', '104338'],
#      'ehid': ['3c42c6de6939d2af51d45e56115b75212964c3ea',
#       '3c42c6de6939d2af51d45e56115b75212964c3ea'],
#      'pmcode': ['ipkdv07t', 'ipkdv07t']},
#     'country': 'United States',
#     'duration': 1099,
#     'epid': ['3c42c6de6939d2af51d45e56115b75212964c3ea'],
#     'event_details': {'slideshow_event': {'true': 2}},
#     'ip': '72.176.58.105',
#     'location': ['38.0', '-97.0'],
#     'page_path': [['www.tasteofhome.com/recipes/course/desserts/lemonade-desserts',
#       1094]],
#     'query_strings': [{'_cmp': ['RecipeOfTheDay'],
#       '_ebid': ['RecipeOfTheDay7/8/2016'],
#       '_mid': ['104749'],
#       'ehid': ['3c42c6de6939d2af51d45e56115b75212964c3ea'],
#       'pmcode': ['IPKDV07T']},
#      {'_cmp': ['RecipeOfTheDay'],
#       '_ebid': ['RecipeOfTheDay7/6/2016'],
#       '_mid': ['104338'],
#       'ehid': ['3c42c6de6939d2af51d45e56115b75212964c3ea'],
#       'pmcode': ['IPKDV07T']}],
#     'records_in_session': 2,
#     'session_start_time': '2016-07-10 09:35:29',
#     'session_start_utc': '1468161329.032',
#     'time_zone': 'not found. Using US/Central',
#     'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; rv:47.0) Gecko/20100101 Firefox/47.0',
#     'value_details': {'content_type': {'slideshow': 2},
#      'link_module': {'slides': 2},
#      'link_name': {'next': 2},
#      'link_page': {'/recipes/course/desserts/lemonade-desserts': 1,
#       '/recipes/ingredients/cucumber-recipes-to-make-this-summer': 1},
#      'link_pos': {'main slides': 2},
#      'page_template': {'slideshow': 2},
#      'type': {'view': 2}}},
#    {'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['recipes~cooking-style~grilling-recipes~top-10-grilled-steak-recipes',
#       5]],
#     'category_page_path': [['recipes~cooking-style~grilling-recipes~top-10-grilled-steak-recipes',
#       'www.tasteofhome.com/recipes/cooking-style/grilling-recipes/top-10-grilled-steak-recipes']],
#     'city': 'temple',
#     'consolidated_query_strings': {'_cmp': ['RecipeOfTheDay'],
#      '_ebid': ['RecipeOfTheDay6/26/2016'],
#      '_mid': ['103125'],
#      'ehid': ['3c42c6de6939d2af51d45e56115b75212964c3ea'],
#      'pmcode': ['IPKDV07T']},
#     'country': 'United States',
#     'duration': 5,
#     'epid': ['3c42c6de6939d2af51d45e56115b75212964c3ea'],
#     'ip': '72.176.58.105',
#     'location': ['38.0', '-97.0'],
#     'page_path': [['www.tasteofhome.com/recipes/cooking-style/grilling-recipes/top-10-grilled-steak-recipes',
#       5]],
#     'query_strings': [{'_cmp': ['RecipeOfTheDay'],
#       '_ebid': ['RecipeOfTheDay6/26/2016'],
#       '_mid': ['103125'],
#       'ehid': ['3c42c6de6939d2af51d45e56115b75212964c3ea'],
#       'pmcode': ['IPKDV07T']}],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-10 11:59:35',
#     'session_start_utc': '1468166199.352',
#     'time_zone': 'not found. Using US/Central',
#     'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; rv:47.0) Gecko/20100101 Firefox/47.0',
#     'value_details': {'content_id': {'543': 1},
#      'content_type': {'slideshow': 1},
#      'link_module': {'slides': 1},
#      'link_name': {'peppered ribeye steaks': 1},
#      'link_page': {'/recipes/cooking-style/grilling-recipes/top-10-grilled-steak-recipes': 1},
#      'link_pos': {'get recipe': 1},
#      'page_template': {'slideshow': 1},
#      'partner_name': {'taste of home': 1},
#      'type': {'hidden': 1}}}],
#   '11131ee0-410c-433e-83c7-7e5eeb4a5cdd'),
#  ('108.240.90.0#19401FB5',
#   'tasteofhome',
#   '2015-05-09',
#   [{'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['recipes', 5]],
#     'category_page_path': [['recipes',
#       'www.tasteofhome.com/recipes/favorite-baked-spaghetti']],
#     'city': 'cincinnati',
#     'country': 'United States',
#     'duration': 5,
#     'ip': '108.240.90.0',
#     'location': ['39.6474', '-84.1573'],
#     'page_path': [['www.tasteofhome.com/recipes/favorite-baked-spaghetti', 5]],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-10 10:06:01',
#     'session_start_utc': '1468159561.222',
#     'time_zone': 'America/New_York',
#     'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_2 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13F69 Safari/601.1',
#     'value_details': {'content_id': {'26331': 1},
#      'content_type': {'recipe detail': 1},
#      'page_no': {'view all': 1},
#      'partner_name': {'quick cooking': 1},
#      'rel_content': {'related recipes': 1},
#      'type': {'view': 1}}},
#    {'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['recipes', 5]],
#     'category_page_path': [['recipes',
#       'www.tasteofhome.com/recipes/pink-lemonade-stand-cake']],
#     'city': 'cincinnati',
#     'consolidated_query_strings': {'_cmp': ['Top10'],
#      '_ebid': ['Top107/10/2016'],
#      '_mid': ['104845'],
#      'ehid': ['FD2937D24D43163C1C2610602547B6FAF4559E5B'],
#      'pmcode': ['IPIDC01T']},
#     'country': 'United States',
#     'duration': 5,
#     'epid': ['fd2937d24d43163c1c2610602547b6faf4559e5b'],
#     'event_details': {'email_event': {'true': 1}},
#     'ip': '108.240.90.0',
#     'location': ['39.6474', '-84.1573'],
#     'page_path': [['www.tasteofhome.com/recipes/pink-lemonade-stand-cake', 5]],
#     'query_strings': [{'_cmp': ['Top10'],
#       '_ebid': ['Top107/10/2016'],
#       '_mid': ['104845'],
#       'ehid': ['FD2937D24D43163C1C2610602547B6FAF4559E5B'],
#       'pmcode': ['IPIDC01T']}],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-11 05:52:37',
#     'session_start_utc': '1468195159.189',
#     'time_zone': 'America/New_York',
#     'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_2 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13F69 Safari/601.1',
#     'value_details': {'content_id': {'178236': 1},
#      'content_type': {'recipe detail': 1},
#      'email_blast_id': {'top107/10/2016': 1},
#      'email_campaign': {'top10': 1},
#      'page_no': {'view all': 1},
#      'partner_name': {'taste of home': 1},
#      'rel_content': {'related recipes': 1},
#      'type': {'view': 1}}}],
#   '7c76715e-42d1-4ccd-ac4f-3999f59136c9'),
#  ('14909733-1990-3011-5011-146586498500',
#   'tasteofhome',
#   '2015-05-09',
#   [{'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'categories_viewed': [['recipes~cooking-style~grilling-recipes~how-to-cook-in-foil-packets',
#       1674]],
#     'category_page_path': [['recipes~cooking-style~grilling-recipes~how-to-cook-in-foil-packets',
#       'www.tasteofhome.com/recipes/cooking-style/grilling-recipes/how-to-cook-in-foil-packets']],
#     'city': 'fair oaks',
#     'consolidated_query_strings': {'_cmp': ['TOHContentTOH'],
#      '_ebid': ['TOHContentTOH7/9/2016'],
#      '_mid': ['104813'],
#      'ehid': ['394DFC4925AB7852DD2568F1B871538F485F838D']},
#     'country': 'United States',
#     'duration': 1679,
#     'epid': ['394dfc4925ab7852dd2568f1b871538f485f838d'],
#     'internal_referrers': ['www.tasteofhome.com/recipes/course/salads/salad-recipes-ready-in-30-minutes'],
#     'ip': '108.240.188.0',
#     'location': ['38.5574', '-121.321'],
#     'page_path': [['www.tasteofhome.com/recipes/cooking-style/grilling-recipes/how-to-cook-in-foil-packets',
#       1674]],
#     'query_strings': [{'_cmp': ['TOHContentTOH'],
#       '_ebid': ['TOHContentTOH7/9/2016'],
#       '_mid': ['104813'],
#       'ehid': ['394DFC4925AB7852DD2568F1B871538F485F838D']}],
#     'records_in_session': 2,
#     'session_start_time': '2016-07-10 08:02:50',
#     'session_start_utc': '1468162970.364',
#     'time_zone': 'America/Los_Angeles',
#     'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2486.0 Safari/537.36 Edge/13.10586',
#     'value_details': {'content_id': {'12372': 1, '89850': 1},
#      'content_type': {'recipe detail': 1, 'slideshow': 1},
#      'link_module': {'slides': 1},
#      'link_name': {'crab & shrimp stuffed sole': 1},
#      'link_page': {'/recipes/cooking-style/grilling-recipes/how-to-cook-in-foil-packets': 1},
#      'link_pos': {'get recipe': 1},
#      'page_no': {'view all': 1},
#      'page_template': {'slideshow': 1},
#      'partner_name': {'country woman': 1, 'quick cooking': 1},
#      'rel_content': {'related recipes': 1},
#      'type': {'hidden': 1, 'view': 1}}},
#    {'categories_shared_on_facebook': 'None',
#     'categories_shared_on_google_plus': 'None',
#     'categories_shared_on_pinterest': 'None',
#     'categories_shared_on_twitter': 'None',
#     'category_page_path': [['', 'www.tasteofhome.com/']],
#     'city': 'fair oaks',
#     'country': 'United States',
#     'duration': 5,
#     'epid': ['394dfc4925ab7852dd2568f1b871538f485f838d'],
#     'external_referrers': ['www.bing.com/'],
#     'ip': '108.240.188.0',
#     'location': ['38.5574', '-121.321'],
#     'page_path': [['www.tasteofhome.com/', 5]],
#     'records_in_session': 1,
#     'session_start_time': '2016-07-10 09:36:23',
#     'session_start_utc': '1468166614.059',
#     'time_zone': 'America/Los_Angeles',
#     'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2486.0 Safari/537.36 Edge/13.10586',
#     'value_details': {'content_type': {'6': 1},
#      'link_module': {'feature- feature': 1},
#      'link_name': {'next': 1},
#      'link_page': {'/': 1},
#      'page_template': {'home': 1},
#      'type': {'hidden': 1}}}],
#   'b1619fd4-3600-4b86-af29-28d12547f6b3')]

# %%
### Category Counts - Checks if already processed and returns only non processed dates
### given a ragne of dates, last date is excluded : 15-18 means 15,16,17
dates = [datetime(2016,4,x) for x in range(15,18)]
#dates = [datetime(2016,4,7)]
cats = site_combos_to_process(dates)
process_category_combos(data_S3FilePattern, header, cats, sqlCtx)

# %%
### Site and page counting

PageSiteCounter
